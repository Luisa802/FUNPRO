# %% [markdown]
# TALLER 22/SEPTIEMBRE

# %% [markdown]
# ![WhatsApp Image 2025-09-22 at 10.36.01 AM.jpeg](data:image/jpeg;base64,...)

# %%
#Verificar si un numero es positivo,negativo o cero
numero = int(input("Ingrese un numero:"))
if numero>0 :
  print("El numero es positivo")
elif numero<0 :
  print("El numero es negativo")
elif numero ==0:
  print("el numero es cero")
else:
  print ("ninguna de las anteriores")
# Out:
# Ingrese un numero:5
# El numero es positivo

# %% [markdown]
# ![WhatsApp Image 2025-09-22 at 10.36.02 AM.jpeg](data:image/jpeg;base64,...)

# %%
#Determina si e un año bisiesto
año=int(input("ingrese el año"))
if año % 4 ==0:
  print("el años es bisiesto")
elif año % 400 ==0:
  print("el año es bisiesto")
else:
  print(f"el año ingresado {año} no es bisiesto")
# Out:
# ingrese el año2025
# el año ingresado 2025 no es bisiesto

# %% [markdown]
# ![WhatsApp Image 2025-09-22 at 10.36.02 AM (1).jpeg](data:image/jpeg;base64,...)

# %%
# calculadora de indice de masa corporal
P=float(input("ingrese su peso en kg: "))
A=float(input("ingrese su altura en m: "))
IMC=P/(A**2)
if IMC<18.5:
  print("bajo peso")
elif IMC>=19.5 or IMC<=24.9:
  print("peso normal")
elif IMC>=25 or IMC<=29:
  print("sobrepeso")
else:
 print("el IMC ingresado es obesidad")
# Out:
# ingrese su peso en kg: 20
# ingrese su altura en m: 30
# bajo peso
