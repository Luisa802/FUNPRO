# %% [markdown]
# <a href="https://colab.research.google.com/github/Luisa802/FUNPRO/blob/main/Ejercicio%2012/11/2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def notas_mayores3():
  n_notas=len(notas)
  notas=[]
  i=1
  suma=0
  cont=0
  n_notoas=int(input("Ingrese la cantidad de notas: "))
  for i in range(n_notas):
    notas=float(input("Ingrese la nota: "))
    notas.apped(notas)
  i=1
  suma=0
  cont=0
  while i<=n_notas:
    if notas[i]>3:
      print(f"mostrar nota {notas[i]}")
      suma=suma+notas[i]
      cont=cont+1
    i=i+1

  prom=suma/cont
  print(f"Este es el promedio {prom}")

# %% [markdown]
# ![4947259785183169325.jpg](data:image/jpeg;base64,...)
