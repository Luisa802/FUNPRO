# %% [markdown]
# <a href="https://colab.research.google.com/github/Luisa802/FUNPRO/blob/main/Tarea_15_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![WhatsApp Image 2025-10-15 at 10.22.53 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# CORRECIÓN EJERCICIO 1 Y 2
#
# Ejercicio 1:
# ![photo_5152222621050014517_y.jpg](data:image/jpeg;base64,...)

# %%
cero=0
n=int(input("Ingrese la cantidad de números a analizar: "))
for i in range(1,n+1):
  num=int(input(f"Ingrese el numero {i}: "))
  if num==0: cero=cero+1
print(f"La cantidad de ceros en {n} números es {cero} ")
# Out:
# Ingrese la cantidad de números a analizar: 2
# Ingrese el numero 1: 10
# Ingrese el numero 2: 5
# La cantidad de ceros en 2 números es 0

# %% [markdown]
# Ejercicio 2
# ![photo_5152222621050014518_y.jpg](data:image/jpeg;base64,...)

# %%
#promedio de pares y suma de impares
#50 números cualesquiera
impar=0
pares=0
n=0

for i in range(5):#Quiero que se repita una cantidad de veces, en este caso, 10
  num=int(input("Ingrese un número: "))
  if num%2==0:
    pares=pares+num
    n=n+1
  else: impar=impar+num

print(f"La suma de los números impares es {impar}")
print(f"El promedio de los números pares es {pares/n}")
# Out:
# Ingrese un número: 2
# Ingrese un número: 10
# Ingrese un número: 8
# Ingrese un número: 3
# Ingrese un número: 7
# La suma de los números impares es 10
# El promedio de los números pares es 6.666666666666667

# %% [markdown]
# Ejercicio tres
# ![photo_5152547509556153144_y.jpg](data:image/jpeg;base64,...)

# %%
cuno=0
i=1
cifras=int(input("ingresar la cantidad de cifras a analizar:"))
for i in range(1,cifras+1):
  num=int(input(f"ingrese el número {i}:"))
  if num==1:
    cuno=cuno+1
print(f"hay {cuno} en {cifras} cifras")
# Out:
# ingresar la cantidad de cifras a analizar:4
# ingrese el número 1:1
# ingrese el número 2:5
# ingrese el número 3:4
# ingrese el número 4:1
# hay 2 en 4 cifras
